# %%
import pandas as pd
csv_df = pd.read_csv('belize_airbnb_listings.csv', delimiter=';')

csv_df.head()

# %%
#Create a new dataframe that takes the original dataset and groups 
# the data by neighborhood and finds the average price, total 
# number of reviews, and max availability_365.

#In short, you’re looking for the average price, 
# total number of reviews, and max availability per neighborhood.

import numpy as np
belize_df[['price','number_of_reviews','max_availability']].mean
