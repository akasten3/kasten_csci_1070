# %% [markdown]
# 1.
# for each number in (Enter a list: )
#
# if number < 0:
#
# place in list A
#
# if number > 0:
#
# place in list B
#
# return list A, list B

# %%
# 2. 
import numpy as np
import pandas as pd
jeopardy_df = pd.read_csv('JEOPARDY_DATA.csv')

#clean so that round uses one hot encoding instead of categorical and value shows a decimal type when you do a type check
jeopardy_df.columns = jeopardy_df.columns.str.replace(' ','')
jeopardy_df.columns = jeopardy_df.columns.str.replace('$','')

jeopardy_df = float('Value')

jeopardy_df = pd.get_dummies(jeopardy_df[["Round"]])

jeopardy_df
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[37], line 10
#       7 jeopardy_df.columns = jeopardy_df.columns.str.replace(' ','')
#       8 jeopardy_df.columns = jeopardy_df.columns.str.replace('$','')
# ---> 10 jeopardy_df = float('Value')
#      12 jeopardy_df = pd.get_dummies(jeopardy_df[["Round"]])
#      14 jeopardy_df
#
# ValueError: could not convert string to float: 'Value'

# %% [markdown]
# ## Bonus
# it is probably inconvenient because a lot of the data will come in str form with dollar signs attached. it creates more steps when cleaning up the data in preprocessing.
