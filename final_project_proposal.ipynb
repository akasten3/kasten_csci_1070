# %% [markdown]
# 1. Are you working alone or with someone else? If working with someone please put their name.
#     - What is your plan for working on this? How much time do you plan to dedicate to working on your project? If working with a partner, how will you coordinate to work on the project?
#
# 2. What dataset are you going to use (you can select more or less anything not already used in class or homework)?
#
# 3. What is your starting hypothesis about the data? Create a null hypothesis and an alternative hypothesis as follows:
#     - Null: For the dataset <describe your dataset> there will be no difference between <possible outcomes>
#     - Alternative: For the dataset <describe your dataset> there will be a difference in the <possible outcomes>.
#     - You want to prove the alternative hypothesis is true, but it isn't necessarily a problem if you cannot.
#
# 4. What models do you plan to apply to your data first?

# %% [markdown]
# 1. I will be working alone. I plan to spend my mornings working on this project. I am always free until 11AM, which gives me time to dedicate to this project.
#
# 2. I'm thinking of using the Maternal, Child, and Adolescent Health Needs Assessment data set, which is about the health needs of people at different ages throughout their lives.
#
# 3. My null hypothesis is that there is no correlation between the health condition someone has and their cause of death. My alternative hypothesis is that there is a correlation between the health condition someone has and their cause of death.
#
# 4. I think KNN would make sense for this dataset, so I would start there.

# %%
import pandas as pd
health_df = pd.read_csv("Maternal__Child__and_Adolescent_Health_Needs_Assessment__2023-2024.csv")
health_df.head()
# Out:
#      Age_group  Sex             Topic         Data_source  \
# 0  0to12months  ALL  HEALTH CONDITION  CDPH BIRTH RECORDS
# 1  0to12months  ALL  HEALTH CONDITION  CDPH BIRTH RECORDS
# 2  0to12months  ALL  HEALTH CONDITION  CDPH BIRTH RECORDS
# 3  0to12months  ALL  HEALTH CONDITION  CDPH BIRTH RECORDS
# 4  0to12months  ALL  HEALTH CONDITION  CDPH BIRTH RECORDS
#
#                         Health_condition-Data_source     Period    Year  \
# 0  ASSISTED VENTILATION FOR >6 HOURS - CDPH BIRTH...       2019  2019.0
# 1  ASSISTED VENTILATION FOR >6 HOURS - CDPH BIRTH...       2020  2020.0
# 2  ASSISTED VENTILATION FOR >6 HOURS - CDPH BIRTH...       2021  2021.0
# 3  ASSISTED VENTILATION FOR >6 HOURS - CDPH BIRTH...       2022  2022.0
# 4  ASSISTED VENTILATION FOR >6 HOURS - CDPH BIRTH...  2014-2016     NaN
#
#    Denominator Denominator_is  Number_with_outcome  ... Race_ethnicity  \
# 0       8307.0   TOTAL BIRTHS                 25.0  ...            ALL
# 1       7890.0   TOTAL BIRTHS                 43.0  ...            ALL
# 2       7413.0   TOTAL BIRTHS                 46.0  ...            ALL
# 3       7049.0   TOTAL BIRTHS                 24.0  ...            ALL
# 4       6673.0   TOTAL BIRTHS                 21.0  ...            ALL
#
#                                           Rate_title  \
# 0  Rate of ASSISTED VENTILATION FOR >6 HOURS - CD...
# 1  Rate of ASSISTED VENTILATION FOR >6 HOURS - CD...
# 2  Rate of ASSISTED VENTILATION FOR >6 HOURS - CD...
# 3  Rate of ASSISTED VENTILATION FOR >6 HOURS - CD...
# 4  Rate of ASSISTED VENTILATION FOR >6 HOURS - CD...
#
#                                          Trend_title  Filter_1000_or_more  \
# 0  Rate of ASSISTED VENTILATION FOR >6 HOURS - CD...                20-50
# 1  Rate of ASSISTED VENTILATION FOR >6 HOURS - CD...                20-50
# 2  Rate of ASSISTED VENTILATION FOR >6 HOURS - CD...                20-50
# 3  Rate of ASSISTED VENTILATION FOR >6 HOURS - CD...                20-50
# 4  Rate of ASSISTED VENTILATION FOR >6 HOURS - CD...                20-50
#
#    Sort_1000_or_more Primary_Neighborhood Cause of death rank Death_tooltip  \
# 0                  4                  All                 NaN           NaN
# 1                  4                  All                 NaN           NaN
# 2                  4                  All                 NaN           NaN
# 3                  4                  All                 NaN           NaN
# 4                  4                  All                 NaN           NaN
#
#   Latest_data Unique_row_id
# 0         NaN          5577
# 1         NaN         19728
# 2         NaN         21267
# 3         NaN          4433
# 4         NaN           437
#
# [5 rows x 28 columns]
