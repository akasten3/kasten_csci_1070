# %% [markdown]
# ## Question 1
#
# SELECT *
#
# FROM payment
#
# WHERE amount >= 9.99

# %% [markdown]
# ## Question 2
#
# SELECT max (amount)
#
# FROM payment
#
#
#
#
# SELECT SUM (rental_rate), film_id
#
# FROM film
#
# GROUP BY film_id

# %% [markdown]
# ## Question 3
# SELECT (first_name), last_name, email, address_id
#
# FROM staff

# %% [markdown]
# ## Question 4
# I am mostly looking into how to apply knowledge in the computer science industry to theatre. I work a lot in tech theatre, and more specifically, with lighting and sound boards/softwares and I think it'd be interesting to find out how my work in computer science can be applied to that.
