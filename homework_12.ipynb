# %%
import nltk
import numpy
import pandas as pd
nltk.download('gutenberg')
# Out:
# [nltk_data] Downloading package gutenberg to
# [nltk_data]     C:\Users\kaste\AppData\Roaming\nltk_data...
# [nltk_data]   Package gutenberg is already up-to-date!
# True

# %%
nltk.corpus.gutenberg.fileids()
# Out:
# ['austen-emma.txt',
#  'austen-persuasion.txt',
#  'austen-sense.txt',
#  'bible-kjv.txt',
#  'blake-poems.txt',
#  'bryant-stories.txt',
#  'burgess-busterbrown.txt',
#  'carroll-alice.txt',
#  'chesterton-ball.txt',
#  'chesterton-brown.txt',
#  'chesterton-thursday.txt',
#  'edgeworth-parents.txt',
#  'melville-moby_dick.txt',
#  'milton-paradise.txt',
#  'shakespeare-caesar.txt',
#  'shakespeare-hamlet.txt',
#  'shakespeare-macbeth.txt',
#  'whitman-leaves.txt']

# %%
pl = nltk.corpus.gutenberg.words('milton-paradise.txt')
pl
# Out:
# ['[', 'Paradise', 'Lost', 'by', 'John', 'Milton', ...]

# %%
def word_counts(pl):
	counts = {}

	for x in pl:
		if x not in counts:
			counts[x] = 1
		else:
			counts[x] += 1
	return(counts)
word_counts(pl)
# Out:
# {'[': 2,
#  'Paradise': 54,
#  'Lost': 2,
#  'by': 380,
#  'John': 2,
#  'Milton': 1,
#  '1667': 1,
#  ']': 1,
#  'Book': 12,
#  'I': 589,
#  'Of': 564,
#  'Man': 135,
#  "'": 595,
#  's': 262,
#  'first': 156,
#  'disobedience': 6,
#  ',': 10198,
#  'and': 2799,
#  'the': 2505,
#  'fruit': 59,
#  'that': 536,
#  'forbidden': 8,
#  'tree': 53,
#  'whose': 84,
#  'mortal': 32,
#  'taste': 47,
#  'Brought': 4,
#  'death': 81,
#  'into': 65,
#  'World': 9,
#  'all': 604,
#  'our': 222,
#  'woe': 33,
#  'With': 284,
#  'loss': 20,
#  'of': 1486,
#  'Eden': 26,
#  'till': 92,
#  'one': 114,
#  'greater': 13,
#  'Restore': 1,
#  'us': 179,
#  'regain': 4,
#  'blissful': 7,
#  'seat': 51,
#  'Sing': 1,
#  'Heavenly': 4,
#  'Muse': 4,
#  'on': 434,
#  'secret': 13,
#  'top': 18,
#  'Oreb': 3,
#  'or': 578,
#  'Sinai': 2,
#  'didst': 21,
#  'inspire': 1,
#  'That': 168,
#  'shepherd': 2,
#  'who': 244,
#  'taught': 15,
#  'chosen': 3,
#  'seed': 26,
#  'In': 283,
#  'beginning': 5,
# ...

# %%
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\kaste\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
sw = set(nltk.corpus.stopwords.words('english'))
sw
# Out:
# {'a',
#  'about',
#  'above',
#  'after',
#  'again',
#  'against',
#  'ain',
#  'all',
#  'am',
#  'an',
#  'and',
#  'any',
#  'are',
#  'aren',
#  "aren't",
#  'as',
#  'at',
#  'be',
#  'because',
#  'been',
#  'before',
#  'being',
#  'below',
#  'between',
#  'both',
#  'but',
#  'by',
#  'can',
#  'couldn',
#  "couldn't",
#  'd',
#  'did',
#  'didn',
#  "didn't",
#  'do',
#  'does',
#  'doesn',
#  "doesn't",
#  'doing',
#  'don',
#  "don't",
#  'down',
#  'during',
#  'each',
#  'few',
#  'for',
#  'from',
#  'further',
#  'had',
#  'hadn',
#  "hadn't",
#  'has',
#  'hasn',
#  "hasn't",
#  'have',
#  'haven',
#  "haven't",
#  'having',
#  'he',
#  "he'd",
#  "he'll",
#  "he's",
#  'her',
#  'here',
#  'hers',
#  'herself',
#  'him',
#  'himself',
#  'his',
#  'how',
#  'i',
#  "i'd",
#  "i'll",
#  "i'm",
#  "i've",
#  'if',
#  'in',
#  'into',
#  'is',
#  'isn',
#  "isn't",
#  'it',
#  "it'd",
#  "it'll",
#  "it's",
#  'its',
#  'itself',
#  'just',
#  'll',
#  'm',
#  'ma',
# ...

# %%
text_sentences = nltk.corpus.gutenberg.sents('milton-paradise.txt')[:10]
text_sentences
# Out:
# ---------------------------------------------------------------------------
# LookupError                               Traceback (most recent call last)
# File c:\Users\kaste\AppData\Local\Programs\Python\Python311\Lib\site-packages\nltk\corpus\reader\plaintext.py:89, in PlaintextCorpusReader.sents(self, fileids)
#      88 try:
# ---> 89     self._sent_tokenizer = PunktTokenizer()
#      90 except Exception:
#
# File c:\Users\kaste\AppData\Local\Programs\Python\Python311\Lib\site-packages\nltk\tokenize\punkt.py:1746, in PunktTokenizer.__init__(self, lang)
#    1745 PunktSentenceTokenizer.__init__(self)
# -> 1746 self.load_lang(lang)
#
# File c:\Users\kaste\AppData\Local\Programs\Python\Python311\Lib\site-packages\nltk\tokenize\punkt.py:1751, in PunktTokenizer.load_lang(self, lang)
#    1749 from nltk.data import find
# -> 1751 lang_dir = find(f"tokenizers/punkt_tab/{lang}/")
#    1752 self._params = load_punkt_params(lang_dir)
#
# ...

# %%
# nltk.download('vader_lexicon')
from nltk.sentiment.vader import SentimentIntensityAnalyzer

analyzer = SentimentIntensityAnalyzer()

# %%
sentiment = analyzer.polarity_scores(pl)
print(sentiment)

#really not sure why this isn't working, i used the code we used in class
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[32], line 1
# ----> 1 sentiment = analyzer.polarity_scores(pl)
#       2 print(sentiment)
#       4 #really not sure why this isn't working, i used the code we used in class
#
# File c:\Users\kaste\AppData\Local\Programs\Python\Python311\Lib\site-packages\nltk\sentiment\vader.py:366, in SentimentIntensityAnalyzer.polarity_scores(self, text)
#     355 """
#     356 Return a float for sentiment strength based on the input text.
#     357 Positive values are positive valence, negative value are negative
#    (...)    363     matched as if it was a normal word in the sentence.
#     364 """
#     365 # text, words_and_emoticons, is_cap_diff = self.preprocess(text)
# --> 366 sentitext = SentiText(
#     367     text, self.constants.PUNC_LIST, self.constants.REGEX_REMOVE_PUNCTUATION
#     368 )
#     369 sentiments = []
# ...

# %%
import pandas as pd
sentiments = []
compound = sentiment['compound']
pos = sentiment['pos']
neg = sentiment['neg']
neu = sentiment['neu']

sentiments.append({
    "text": text,
    "compound": compound,
    "positive": pos,
    "negative": neg,
    "neutral": neu
})

pd.DataFrame(sentiments)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[33], line 3
#       1 import pandas as pd
#       2 sentiments = []
# ----> 3 compound = sentiment['compound']
#       4 pos = sentiment['pos']
#       5 neg = sentiment['neg']
#
# NameError: name 'sentiment' is not defined

# %%
for sentence in pl:
     sid = SentimentIntensityAnalyzer()
     print(sentence)
     ss = sid.polarity_scores(sentence)
     for k in sorted(ss):
         print('{0}: {1}, '.format(k, ss[k]), end='')
     print()

     #im not sure why this did sentiment analysis on words instead of sentences
# Out:
# [
# compound: 0.0, neg: 0.0, neu: 0.0, pos: 0.0,
# Paradise
# compound: 0.6369, neg: 0.0, neu: 0.0, pos: 1.0,
# Lost
# compound: -0.3182, neg: 1.0, neu: 0.0, pos: 0.0,
# by
# compound: 0.0, neg: 0.0, neu: 1.0, pos: 0.0,
# John
# compound: 0.0, neg: 0.0, neu: 1.0, pos: 0.0,
# Milton
# compound: 0.0, neg: 0.0, neu: 1.0, pos: 0.0,
# 1667
# compound: 0.0, neg: 0.0, neu: 1.0, pos: 0.0,
# ]
# compound: 0.0, neg: 0.0, neu: 0.0, pos: 0.0,
# Book
# compound: 0.0, neg: 0.0, neu: 1.0, pos: 0.0,
# I
# compound: 0.0, neg: 0.0, neu: 0.0, pos: 0.0,
# Of
# compound: 0.0, neg: 0.0, neu: 1.0, pos: 0.0,
# Man
# compound: 0.0, neg: 0.0, neu: 1.0, pos: 0.0,
# '
# compound: 0.0, neg: 0.0, neu: 0.0, pos: 0.0,
# s
# compound: 0.0, neg: 0.0, neu: 0.0, pos: 0.0,
# first
# compound: 0.0, neg: 0.0, neu: 1.0, pos: 0.0,
# disobedience
# compound: 0.0, neg: 0.0, neu: 1.0, pos: 0.0,
# ,
# compound: 0.0, neg: 0.0, neu: 0.0, pos: 0.0,
# and
# compound: 0.0, neg: 0.0, neu: 1.0, pos: 0.0,
# the
# ...

# %%
neut = []
neg = []
pos = []
for k in ss:
    if 'neutral' in ss == 1.0:
        neut == k

    elif 'negative' in ss == 1.0:
        neg += 1

    elif 'positive' in ss == 1.0:
        pos += 1

print(neut, neg, pos)
# Out:
# [] [] []
